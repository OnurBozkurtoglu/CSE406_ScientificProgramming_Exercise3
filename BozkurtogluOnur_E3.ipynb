# %% [markdown]
# <h1> Exercise 3</h1>
# <p>Onur Bozkurtoğlu</p>
# <p>20170808044</p>
# <h2>7    File I/O</h2>
# <h3>Exercise 7.1: Open a file</h3>
# <h4>Write a function that opens a file (input: filename), and prints the file line by line.</h4>

# %%
def open_file(filename):
    with open(filename, "r") as file:
        for line in file:
            print(line, end = '')

# %% [markdown]
# <h3>Exercise 7.2: Wordcount</h3>
# <h4>On the course website you can find a text file containing the complete works of William Shapespeare.</h4>
# <h4>(a) Find the 20 most common words</h4>

# %%
from collections import Counter
import re

def find_most_common_20_words(filename):
    with open(filename, "r") as file:
        text = file.read()
        words = re.findall(r'[\w]+', text)
        print(Counter(words).most_common(20))

# %% [markdown]
# <h4>(b) How many unique words are used?</h4>

# %%
import re
def find_unique_words(filename):
    with open(filename, "r") as file:
        text = file.read()
        words = re.findall(r'[\w]+', text.lower())
        unique_words = set(words)
        print(len(unique_words))
find_unique_words("shakespeare.txt")
# Out:
# 24010

# %% [markdown]
# <h4>(c) How many words are used at least 5 times?</h4>

# %%
import string
def find_words_used_at_least_5_times(filename):
    with open(filename, "r") as file:
        d = dict()
        for line in file:
            line = line.strip()
            line = line.lower()
            line = line.translate(line.maketrans("", "", string.punctuation))
            words = line.split(" ")
            for word in words:
                if word in d:
                    d[word] = d[word] + 1
                else:
                    d[word] = 1
        count = 0
        for i in d:
            if int(d.get(i)) >= 5:
                count = count + 1
        print(count)

# %% [markdown]
# <h4>(d) Write the 200 most common words, and their counts, to a file.</h4>

# %%
from collections import Counter
import re

def find_most_common_20_words(filename):
    with open("shakespeare.txt", "r") as file:
        text = file.read()
        words = re.findall(r'[\w]+', text)
        my_list = Counter(words).most_common(200)
        with open(filename, "r+") as file_write: 
            for tuples in my_list:
                file_write.write("\n")
                for i in range(len(tuples)):
                    file_write.write(str(tuples[i]) + " ")

# %% [markdown]
# <h3>Exercise 7.4: Sum of lists</h3>
# <h4>Before you start coding, please read the entire problem</h4>
# <h4>(a) Data generation</h4>
# <h4>Write a function that takes three integers, n, a and b and a filename and writes to the file a list
# with n random integers between a and b.</h4>

# %%
import random
def data_generation(n, a, b, filename):
    numbers = [random.randint(a, b) for i in range(n)]
    with open(filename, "w") as file:
        for element in numbers:
            file.write(str(element) + "\n")

# %% [markdown]
# <h4>(b) Reading the data</h4>
# <h4>Write a function that can read the files as generated above and return the values.</h4>

# %%
def read_data(filename):
    my_list = []
    with open(filename, "r") as file:
        for line in file:
            strippled_line = line.rstrip()
            my_list.append(int(strippled_line))
    return my_list

# %% [markdown]
# <h4>(c) Sum problem</h4>
# <h4>Write a function that given two filenames (pointing to files as generated by the above function) and
# an integer k, finds all u and v such that u + v = k, and u is an element of the first list and v is a
# member of the second list.</h4>

# %%
def sum_problem(filename1, filename2, k):
    file1_values = read_data(filename1)
    file2_values = read_data(filename2)
    
    result_u = [u for u in file1_values for v in file2_values if u + v ==k]
    result_v = [v for u in file1_values for v in file2_values if u + v ==k]
    result_k = [k for u in file1_values for v in file2_values if u + v ==k]
    for i in range(len(result_v)):
        print(str(result_u[i]) + " + " + str(result_v[i]) + " equals " + 
              str(result_k[i]))

# %% [markdown]
# <h4>(d) Testing</h4>
# <h4>Test your functions by generating 2 files with n = 2000, a = 1, b = 10000 and k = 5000 and
# k = 12000.</h4>

# %%
data_generation(2000, 1, 10000, "test1.txt")
data_generation(2000, 1, 10000, "test2.txt")
sum_problem("test1.txt", "test2.txt", 5000)
sum_problem("test1.txt", "test2.txt", 12000)
# Out:
# 2724 + 2276 equals 5000
# 1978 + 3022 equals 5000
# 2247 + 2753 equals 5000
# 4333 + 667 equals 5000
# 1938 + 3062 equals 5000
# 309 + 4691 equals 5000
# 3260 + 1740 equals 5000
# 1284 + 3716 equals 5000
# 3051 + 1949 equals 5000
# 1954 + 3046 equals 5000
# 4420 + 580 equals 5000
# 3290 + 1710 equals 5000
# 1002 + 3998 equals 5000
# 1397 + 3603 equals 5000
# 2345 + 2655 equals 5000
# 4447 + 553 equals 5000
# 544 + 4456 equals 5000
# 2895 + 2105 equals 5000
# 277 + 4723 equals 5000
# 1732 + 3268 equals 5000
# 1732 + 3268 equals 5000
# 3829 + 1171 equals 5000
# 3696 + 1304 equals 5000
# 36 + 4964 equals 5000
# 663 + 4337 equals 5000
# 710 + 4290 equals 5000
# 1637 + 3363 equals 5000
# 4333 + 667 equals 5000
# 360 + 4640 equals 5000
# 4720 + 280 equals 5000
# 3981 + 1019 equals 5000
# 4427 + 573 equals 5000
# 3191 + 1809 equals 5000
# 2803 + 2197 equals 5000
# 2603 + 2397 equals 5000
# 3476 + 1524 equals 5000
# 4016 + 984 equals 5000
# 190 + 4810 equals 5000
# 1430 + 3570 equals 5000
# ...

# %% [markdown]
# <h4>(e) Bonus: Efficiency</h4>
# <h4>If you are up to a challenge, write a function that solves the sum problem with the restriction that
# you can only go over every number in the both lists once</h4>

# %%
def sum_problem(filename1, filename2, k):
    file1_values = read_data(filename1)
    file2_values = read_data(filename2)
    
    result_u = [u for u in file1_values for v in file2_values if u + v ==k]
    result_v = [v for u in file1_values for v in file2_values if u + v ==k]
    result_k = [k for u in file1_values for v in file2_values if u + v ==k]
    for i in range(len(result_v)):
        print(str(result_u[i]) + " + " + str(result_v[i]) + " equals " + 
              str(result_k[i]))

# %% [markdown]
# <h2>8    Classes</h2>
# <h3>Exercise 8.1: Rational numbers</h3>
# <h4>In this problem, we will write a class that can represent rational numbers, i.e. fractions p/q
# .</h4>
# <h4>(a) Create a class Rational which is initialized by two integers, p and q, the nominator and denominator</h4>

# %%
class Rational:
    def __init__(self, p, q):
        self.p = p
        self.q = q

# %% [markdown]
# <h4>(b) Add a method to print the rational number as p/q (the __str__ or __repr__ method is useful).</h4>

# %%
class Rational:
    def __init__(self, p, q):
        self.p = p
        self.q = q
    def __str__(self):
        return "{} / {}".format(self.p, self.q)

# %% [markdown]
# <h4>(c) We would like to represent 10/20 by 1/2 instead, hence write a function that computes the greatest
# common divisor, and ensure that every rational number is simplified</h4>

# %%
import math
class Rational:
    def __init__(self, p, q):
        self.p = int(p / math.gcd(p,q))
        self.q = int(q / math.gcd(p,q))
    def __str__(self):
        return "{} / {}".format(self.p, self.q)
    def gcd(self, a, b):
        return int(math.gcd(a,b))
rational_number = Rational(10, 20)
print(rational_number)
# Out:
# 1 / 2

# %% [markdown]
# <h4>(d) Add a method so that we can add two rational numbers with r1 + r2, here the __add__() method
# is useful.</h4>

# %%
import math
class Rational:
    def __init__(self, p, q):
        self.p = int(p / math.gcd(p,q))
        self.q = int(q / math.gcd(p,q))
    def __str__(self):
        return "{} / {}".format(self.p, self.q)
    def gcd(self, a, b):
        return int(math.gcd(a,b))
    def __add__(rational_number1, rational_number2):
        result = Rational(rational_number1.p * rational_number2.q + rational_number1.q * rational_number2.p, rational_number1.q * rational_number2.q )
        return result

# %%
a = Rational(2,3)
b = Rational(4,5)
result = Rational.__add__(a, b)
print(result.__str__())
# Out:
# 22 / 15

# %% [markdown]
# <h4>(e) Add a method to subtract two rational numbers. (__sub__)</h4>

# %%
import math
class Rational:
    def __init__(self, p, q):
        self.p = int(p / math.gcd(p,q))
        self.q = int(q / math.gcd(p,q))
    def __str__(self):
        return "{} / {}".format(self.p, self.q)
    def gcd(self, a, b):
        return int(math.gcd(a,b))
    def __add__(rational_number1, rational_number2):
        result = Rational(rational_number1.p * rational_number2.q + rational_number1.q * rational_number2.p, rational_number1.q * rational_number2.q )
        return result
    def __sub__(rational_number1, rational_number2):
        result = Rational(rational_number1.p * rational_number2.q - rational_number1.q * rational_number2.p, rational_number1.q * rational_number2.q )
        return result

# %%
a = Rational(2,3)
b = Rational(4,5)
result = Rational.__sub__(a, b)
print(result.__str__())
# Out:
# -2 / 15

# %% [markdown]
# <h4>(f) Add a method to multiply two rational numbers. (__mul__)</h4>

# %%
import math
class Rational:
    def __init__(self, p, q):
        self.p = int(p / math.gcd(p,q))
        self.q = int(q / math.gcd(p,q))
    def __str__(self):
        return "{} / {}".format(self.p, self.q)
    def gcd(self, a, b):
        return int(math.gcd(a,b))
    def __add__(rational_number1, rational_number2):
        result = Rational(rational_number1.p * rational_number2.q + rational_number1.q * rational_number2.p, rational_number1.q * rational_number2.q )
        return result
    def __sub__(rational_number1, rational_number2):
        result = Rational(rational_number1.p * rational_number2.q - rational_number1.q * rational_number2.p, rational_number1.q * rational_number2.q )
        return result
    def __mul__(rational_number1, rational_number2):
        result = Rational(rational_number1.p * rational_number2.p, rational_number1.q * rational_number2.q)
        return result

# %%
a = Rational(2,3)
b = Rational(4,5)
result = Rational.__mul__(a, b)
print(result.__str__())
# Out:
# 8 / 15

# %% [markdown]
# <h4>(g) Add a method to divide two rational numbers. (__div__)</h4>

# %%
import math
class Rational:
    def __init__(self, p, q):
        self.p = int(p / math.gcd(p,q))
        self.q = int(q / math.gcd(p,q))
    def __str__(self):
        return "{} / {}".format(self.p, self.q)
    def gcd(self, a, b):
        return int(math.gcd(a,b))
    def __add__(rational_number1, rational_number2):
        result = Rational(rational_number1.p * rational_number2.q + rational_number1.q * rational_number2.p, rational_number1.q * rational_number2.q )
        return result
    def __sub__(rational_number1, rational_number2):
        result = Rational(rational_number1.p * rational_number2.q - rational_number1.q * rational_number2.p, rational_number1.q * rational_number2.q )
        return result
    def __mul__(rational_number1, rational_number2):
        result = Rational(rational_number1.p * rational_number2.p, rational_number1.q * rational_number2.q)
        return result
    def __div__(rational_number1, rational_number2):
        result = Rational(rational_number1.p * rational_number2.q, rational_number1.q * rational_number2.p)
        return result

# %%
a = Rational(2,3)
b = Rational(4,5)
result = Rational.__div__(a, b)
print(result.__str__())
# Out:
# 5 / 6

# %% [markdown]
# <h4>(h) Add a method that compares whether two rational numbers are equal.</h4>

# %%
import math
class Rational:
    def __init__(self, p, q):
        self.p = int(p / math.gcd(p,q))
        self.q = int(q / math.gcd(p,q))
    def __str__(self):
        return "{} / {}".format(self.p, self.q)
    def gcd(self, a, b):
        return int(math.gcd(a,b))
    def __add__(rational_number1, rational_number2):
        result = Rational(rational_number1.p * rational_number2.q + rational_number1.q * rational_number2.p, rational_number1.q * rational_number2.q )
        return result
    def __sub__(rational_number1, rational_number2):
        result = Rational(rational_number1.p * rational_number2.q - rational_number1.q * rational_number2.p, rational_number1.q * rational_number2.q )
        return result
    def __mul__(rational_number1, rational_number2):
        result = Rational(rational_number1.p * rational_number2.p, rational_number1.q * rational_number2.q)
        return result
    def __div__(rational_number1, rational_number2):
        result = Rational(rational_number1.p * rational_number2.q, rational_number1.q * rational_number2.p)
        return result
    def is_equal(rational_number1, rational_number2):
        if (rational_number1.p == rational_number2.p and rational_number1.q == rational_number2.q):
            return True
        else:
            return False

# %%
a = Rational(2,3)
b = Rational(4,5)
result = Rational.is_equal(a, b)
print(result.__str__())
b = Rational(2,3)
result = Rational.is_equal(a, b)
print(result.__str__())
# Out:
# False
# True

# %% [markdown]
# <h4>(h) Add a method that compares whether two rational numbers are equal.</h4>

# %%
import math
class Rational:
    def __init__(self, p, q):
        self.p = int(p / math.gcd(p,q))
        self.q = int(q / math.gcd(p,q))
    def __str__(self):
        return "{} / {}".format(self.p, self.q)
    def gcd(self, a, b):
        return int(math.gcd(a,b))
    def __add__(rational_number1, rational_number2):
        result = Rational(rational_number1.p * rational_number2.q + rational_number1.q * rational_number2.p, rational_number1.q * rational_number2.q )
        return result
    def __sub__(rational_number1, rational_number2):
        result = Rational(rational_number1.p * rational_number2.q - rational_number1.q * rational_number2.p, rational_number1.q * rational_number2.q )
        return result
    def __mul__(rational_number1, rational_number2):
        result = Rational(rational_number1.p * rational_number2.p, rational_number1.q * rational_number2.q)
        return result
    def __div__(rational_number1, rational_number2):
        result = Rational(rational_number1.p * rational_number2.q, rational_number1.q * rational_number2.p)
        return result
    def is_equal(rational_number1, rational_number2):
        if (rational_number1.p == rational_number2.p and rational_number1.q == rational_number2.q):
            return True
        else:
            return False
    def __float__(rational_number1):
        result = rational_number1.p / rational_number1.q
        return result

# %%
a = Rational(2,3)
result = Rational.__float__(a)
print(result.__str__())
# Out:
# 0.6666666666666666

# %% [markdown]
# <h3>Exercise 8.5: Implementing the set class</h3>
# <h4>Write a class mySet that has the same basic functionality as the Python set data structure. Base your
# implementation on a dictionary.</h4>

# %%
class mySet:
    def __init__(self, *args):
        self._dict = {}
        for arg in args:
            self.add(arg)

    def __repr__(self):
        import string
        elems = map(repr, self._dict.keys(  ))
        elems.sort(  )
        return "%s(%s)" % (self.__class__.__name__, string.join(elems, ', '))

    def extend(self, args):
        for arg in args:
            self.add(arg)

    def add(self, item):
        self._dict[item] = item

    def remove(self, item):
        del self._dict[item]

    def contains(self, item):
        return self._dict.has_key(item)

    __contains__ = contains

    def __getitem__(self, index):
        return self._dict.keys(  )[index]

    def __iter__(self):
        return iter(self._dict.copy(  ))

    def __len__(self):
        return len(self._dict)

    def items(self):
        result = self._dict.keys(  )
        try: result.sort(  )
        except: pass
        return result

    def __copy__(self):
        return Set(self)

# %% [markdown]
# <h3>Exercise 8.6: Binary search tree</h3>
# <h4>In this exercise, we will implement a binary search tree. See <a href="http://en.wikipedia.org/wiki/Binary_search_tree">wikipedia.org/wiki/Binary_search_tree</a> for an explanation.</h4>
# <h4>(a) Define a class Node, and write the constructor, which takes one argument, value, and initializes
# the left and right children to None.</h4>

# %%
class Node:
    def __init__(self, value = None):
        self.left = None
        self.right = None
        self.value = value

# %% [markdown]
# <h4>(b) Write a function to print the tree.</h4>

# %%
class Node:
    def __init__(self, value = None):
        self.left = None
        self.right = None
        self.value = value
        
    def insert(self, value):
        if not self.value:
            self.value = value
            return
        if self.value == value:
            return
        if value < self.value:
            if self.left:
                self.left.insert(value)
                return
            self.left = Node(value)
            return
        if self.right:
            self.right.insert(value)
            return
        self.right = Node(value)
    
    def preorder(self, values):
        if self.value is not None:
            vals.append(self.values)
        if self.left is not None:
            self.left.preorder(values)
        if self.right is not None:
            self.right.preorder(values)
        return values

    def inorder(self, values):
        if self.left is not None:
            self.left.inorder(values)
        if self.value is not None:
            values.append(self.value)
        if self.right is not None:
            self.right.inorder(values)
        return values

    def postorder(self, values):
        if self.left is not None:
            self.left.postorder(values)
        if self.right is not None:
            self.right.postorder(values)
        if self.value is not None:
            vals.append(self.value)
        return values

# %%
node = Node(10)
node.insert(5)
node.insert(15)
node.insert(4)
node.insert(25)
node.inorder([])
# Out:
# [4, 5, 10, 15, 25]

# %% [markdown]
# <h4>(c) Write a function that inserts a new value in the tree at the right location.</h4>

# %%
class Node:
    def __init__(self, value = None):
        self.left = None
        self.right = None
        self.value = value
        
    def insert(self, value):
        if not self.value:
            self.value = value
            return
        if self.value == value:
            return
        if value < self.value:
            if self.left:
                self.left.insert(value)
                return
            self.left = Node(value)
            return
        if self.right:
            self.right.insert(value)
            return
        self.right = Node(value)
    
    def preorder(self, values):
        if self.value is not None:
            vals.append(self.values)
        if self.left is not None:
            self.left.preorder(values)
        if self.right is not None:
            self.right.preorder(values)
        return values

    def inorder(self, values):
        if self.left is not None:
            self.left.inorder(values)
        if self.value is not None:
            values.append(self.value)
        if self.right is not None:
            self.right.inorder(values)
        return values

    def postorder(self, values):
        if self.left is not None:
            self.left.postorder(values)
        if self.right is not None:
            self.right.postorder(values)
        if self.value is not None:
            vals.append(self.value)
        return values

# %% [markdown]
# <h4>(d) Write a function that looks up a value in the tree.</h4>

# %%
class Node:
    def __init__(self, value = None):
        self.left = None
        self.right = None
        self.value = value
        
    def insert(self, value):
        if not self.value:
            self.value = value
            return
        if self.value == value:
            return
        if value < self.value:
            if self.left:
                self.left.insert(value)
                return
            self.left = Node(value)
            return
        if self.right:
            self.right.insert(value)
            return
        self.right = Node(value)
    
    def preorder(self, values):
        if self.value is not None:
            vals.append(self.values)
        if self.left is not None:
            self.left.preorder(values)
        if self.right is not None:
            self.right.preorder(values)
        return values

    def inorder(self, values):
        if self.left is not None:
            self.left.inorder(values)
        if self.value is not None:
            values.append(self.value)
        if self.right is not None:
            self.right.inorder(values)
        return values

    def postorder(self, values):
        if self.left is not None:
            self.left.postorder(values)
        if self.right is not None:
            self.right.postorder(values)
        if self.value is not None:
            vals.append(self.value)
        return values

    def exists(self, value):
        if value == self.value:
            return True

        if value < self.value:
            if self.left == None:
                return False
            return self.left.exists(value)

        if self.right == None:
            return False
        return self.right.exists(value)

# %%
node2 = Node(45)
node2.exists(45)
# Out:
# True

# %% [markdown]
# <h4>(e) Write a function that removes a value from the tree.</h4>

# %%
class Node:
    def __init__(self, value = None):
        self.left = None
        self.right = None
        self.value = value
        
    def insert(self, value):
        if not self.value:
            self.value = value
            return
        if self.value == value:
            return
        if value < self.value:
            if self.left:
                self.left.insert(value)
                return
            self.left = Node(value)
            return
        if self.right:
            self.right.insert(value)
            return
        self.right = Node(value)
    
    def preorder(self, values):
        if self.value is not None:
            vals.append(self.values)
        if self.left is not None:
            self.left.preorder(values)
        if self.right is not None:
            self.right.preorder(values)
        return values

    def inorder(self, values):
        if self.left is not None:
            self.left.inorder(values)
        if self.value is not None:
            values.append(self.value)
        if self.right is not None:
            self.right.inorder(values)
        return values

    def postorder(self, values):
        if self.left is not None:
            self.left.postorder(values)
        if self.right is not None:
            self.right.postorder(values)
        if self.value is not None:
            vals.append(self.value)
        return values

    def exists(self, value):
        if value == self.value:
            return True

        if value < self.value:
            if self.left == None:
                return False
            return self.left.exists(value)

        if self.right == None:
            return False
        return self.right.exists(value)

    def delete(self, value):
        if self == None:
            return self
        if value < self.value:
            if self.left:
                self.left = self.left.delete(value)
            return self
        if value > self.value:
            if self.right:
                self.right = self.right.delete(value)
            return self
        if self.right == None:
            return self.left
        if self.left == None:
            return self.right
        min_larger_node = self.right
        while min_larger_node.left:
            min_larger_node = min_larger_node.left
        self.value = min_larger_node.value
        self.right = self.right.delete(min_larger_node.value)
        return self

# %%
node3 = Node(60)
node3.insert(75)
node3.insert(44)
node3.inorder([])
node3.delete(75)
node3.inorder([])
# Out:
# [44, 60]
